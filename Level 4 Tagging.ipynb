# %% [markdown]
# ### Tagging

# %% [markdown]
# So here is Mr. James Wilson who wrote about Elon Musk. Here is the following content.
#
# ~~~~
# Musk was born on June 28, 1971, in Pretoria, Gauteng, South Africa,[27] the son of Maye Musk (née Haldeman), a model and dietician from Regina, Saskatchewan, Canada;[28] and Errol Musk, a South African electromechanical engineer, pilot and sailor. He has a younger brother, Kimbal (born 1972), and a younger sister, Tosca (born 1974).[28][29][30][31] His paternal grandmother was British, and he also has Pennsylvania Dutch ancestry,[32][33] and his maternal grandfather was American, from Minnesota.[34] After his parents divorced in 1980, Musk lived mostly with his father in the suburbs of Pretoria.[32]
#
# During his childhood he had an interest in reading and often did so for hours at a time.[35]
#
# At What age did Musk got interested in computing? At age 10, he developed an interest in computing with the Commodore VIC-20.[36] He taught himself computer programming at the age of 12, sold the code for a BASIC-based video game he created called Blastar, to a magazine called PC and Office Technology, for approximately $500. [37][38] A web version of the game is available online.[37][39]
#
# Musk was severely bullied throughout his childhood, and was once hospitalized when a group of boys threw him down a flight of stairs and then beat him until he lost consciousness.[40]
#
# Musk was initially educated at private schools, attending the English-speaking Waterkloof House Preparatory School.
#
# Mr. Singh helped Musk during his initial days when he was severely bullied during his childhood.
#
# Musk later graduated from Pretoria Boys High School and moved to Canada in June 1989, just before his 18th birthday,[41] after obtaining Canadian citizenship through his Canadian-born mother.[42][43] Although at the time Musk had to register to become a Canadian citizen, Bill C-37, which came into law in April of 2009, effectively made his Canadian citizenship retroactive to his birth since he was born in the first generation abroad to a Canadian-born mother. Therefore, with the law change, he is considered to have always been a Canadian citizen by birth.
# ~~~~

# %%
import nltk
from nltk.tokenize import RegexpTokenizer,word_tokenize,sent_tokenize
from nltk.tag import pos_tag

# %%
file = open('TextFile.txt','r')
reader = file.read()

# %% [markdown]
# # Part - 1
#
# ## 1. Tag the given content using POS Tagger
#
# ## 2. Default Tag the entire content with the tag which appears most number of times

# %%
words = word_tokenize(reader)

# %%
tagged = pos_tag(words)

# %%
tag_fd = nltk.FreqDist(tag for (word, tag) in tagged)
freq = tag_fd.most_common()
freq
# Out:
# [('NN', 56),
#  ('NNP', 54),
#  ('IN', 47),
#  ('VBD', 33),
#  ('CD', 31),
#  (',', 30),
#  ('JJ', 28),
#  ('DT', 24),
#  ('RB', 17),
#  ('.', 15),
#  ('CC', 15),
#  ('PRP', 13),
#  ('PRP$', 12),
#  ('VBN', 11),
#  ('NNS', 8),
#  ('TO', 7),
#  ('VB', 6),
#  ('VBZ', 6),
#  ('VBG', 5),
#  ('$', 4),
#  (')', 3),
#  ('(', 3),
#  ('JJR', 2),
#  ('WRB', 2),
#  (':', 1),
#  ('WP', 1),
#  ('RP', 1),
#  ('WDT', 1)]

# %%
most_common = freq[0][0]
most_common
# Out:
# 'NN'

# %%
default_tagger = nltk.DefaultTagger(most_common)
default_tagger.tag(tagged)
# Out:
# [(('Musk', 'NNP'), 'NN'),
#  (('was', 'VBD'), 'NN'),
#  (('born', 'VBN'), 'NN'),
#  (('on', 'IN'), 'NN'),
#  (('June', 'NNP'), 'NN'),
#  (('28', 'CD'), 'NN'),
#  ((',', ','), 'NN'),
#  (('1971', 'CD'), 'NN'),
#  ((',', ','), 'NN'),
#  (('in', 'IN'), 'NN'),
#  (('Pretoria', 'NNP'), 'NN'),
#  ((',', ','), 'NN'),
#  (('Gauteng', 'NNP'), 'NN'),
#  ((',', ','), 'NN'),
#  (('South', 'NNP'), 'NN'),
#  (('Africa', 'NNP'), 'NN'),
#  ((',', ','), 'NN'),
#  (('[', 'VBD'), 'NN'),
#  (('27', 'CD'), 'NN'),
#  ((']', 'IN'), 'NN'),
#  (('the', 'DT'), 'NN'),
#  (('son', 'NN'), 'NN'),
#  (('of', 'IN'), 'NN'),
#  (('Maye', 'NNP'), 'NN'),
#  (('Musk', 'NNP'), 'NN'),
#  (('(', '('), 'NN'),
#  (('née', 'JJ'), 'NN'),
#  (('Haldeman', 'NNP'), 'NN'),
#  ((')', ')'), 'NN'),
#  ((',', ','), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('model', 'NN'), 'NN'),
#  (('and', 'CC'), 'NN'),
#  (('dietician', 'JJ'), 'NN'),
#  (('from', 'IN'), 'NN'),
#  (('Regina', 'NNP'), 'NN'),
#  ((',', ','), 'NN'),
#  (('Saskatchewan', 'NNP'), 'NN'),
#  ((',', ','), 'NN'),
#  (('Canada', 'NNP'), 'NN'),
#  ((';', ':'), 'NN'),
#  (('[', 'VBZ'), 'NN'),
#  (('28', 'CD'), 'NN'),
#  ((']', 'NN'), 'NN'),
#  (('and', 'CC'), 'NN'),
#  (('Errol', 'NNP'), 'NN'),
#  (('Musk', 'NNP'), 'NN'),
#  ((',', ','), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('South', 'JJ'), 'NN'),
#  (('African', 'JJ'), 'NN'),
#  (('electromechanical', 'JJ'), 'NN'),
#  (('engineer', 'NN'), 'NN'),
#  ((',', ','), 'NN'),
#  (('pilot', 'NN'), 'NN'),
#  (('and', 'CC'), 'NN'),
#  (('sailor', 'NN'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('He', 'PRP'), 'NN'),
#  (('has', 'VBZ'), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('younger', 'JJR'), 'NN'),
#  (('brother', 'NN'), 'NN'),
#  ((',', ','), 'NN'),
#  (('Kimbal', 'NNP'), 'NN'),
#  (('(', '('), 'NN'),
#  (('born', 'JJ'), 'NN'),
#  (('1972', 'CD'), 'NN'),
#  ((')', ')'), 'NN'),
#  ((',', ','), 'NN'),
#  (('and', 'CC'), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('younger', 'JJR'), 'NN'),
#  (('sister', 'NN'), 'NN'),
#  ((',', ','), 'NN'),
#  (('Tosca', 'NNP'), 'NN'),
#  (('(', '('), 'NN'),
#  (('born', 'JJ'), 'NN'),
#  (('1974', 'CD'), 'NN'),
#  ((')', ')'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('[', '$'), 'NN'),
#  (('28', 'CD'), 'NN'),
#  ((']', 'NNP'), 'NN'),
#  (('[', 'VBD'), 'NN'),
#  (('29', 'CD'), 'NN'),
#  ((']', 'NNP'), 'NN'),
#  (('[', 'VBD'), 'NN'),
#  (('30', 'CD'), 'NN'),
#  ((']', 'NNP'), 'NN'),
#  (('[', 'VBD'), 'NN'),
#  (('31', 'CD'), 'NN'),
#  ((']', 'IN'), 'NN'),
#  (('His', 'PRP$'), 'NN'),
#  (('paternal', 'JJ'), 'NN'),
#  (('grandmother', 'NN'), 'NN'),
#  (('was', 'VBD'), 'NN'),
#  (('British', 'JJ'), 'NN'),
#  ((',', ','), 'NN'),
#  (('and', 'CC'), 'NN'),
#  (('he', 'PRP'), 'NN'),
#  (('also', 'RB'), 'NN'),
#  (('has', 'VBZ'), 'NN'),
#  (('Pennsylvania', 'NNP'), 'NN'),
#  (('Dutch', 'NNP'), 'NN'),
#  (('ancestry', 'NN'), 'NN'),
#  ((',', ','), 'NN'),
#  (('[', 'VBZ'), 'NN'),
#  (('32', 'CD'), 'NN'),
#  ((']', 'NN'), 'NN'),
#  (('[', 'VBD'), 'NN'),
#  (('33', 'CD'), 'NN'),
#  ((']', 'NN'), 'NN'),
#  (('and', 'CC'), 'NN'),
#  (('his', 'PRP$'), 'NN'),
#  (('maternal', 'JJ'), 'NN'),
#  (('grandfather', 'NN'), 'NN'),
#  (('was', 'VBD'), 'NN'),
#  (('American', 'JJ'), 'NN'),
#  ((',', ','), 'NN'),
#  (('from', 'IN'), 'NN'),
#  (('Minnesota', 'NNP'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('[', 'CC'), 'NN'),
#  (('34', 'CD'), 'NN'),
#  ((']', 'NN'), 'NN'),
#  (('After', 'IN'), 'NN'),
#  (('his', 'PRP$'), 'NN'),
#  (('parents', 'NNS'), 'NN'),
#  (('divorced', 'VBN'), 'NN'),
#  (('in', 'IN'), 'NN'),
#  (('1980', 'CD'), 'NN'),
#  ((',', ','), 'NN'),
#  (('Musk', 'NNP'), 'NN'),
#  (('lived', 'VBD'), 'NN'),
#  (('mostly', 'RB'), 'NN'),
#  (('with', 'IN'), 'NN'),
#  (('his', 'PRP$'), 'NN'),
#  (('father', 'NN'), 'NN'),
#  (('in', 'IN'), 'NN'),
#  (('the', 'DT'), 'NN'),
#  (('suburbs', 'NN'), 'NN'),
#  (('of', 'IN'), 'NN'),
#  (('Pretoria', 'NNP'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('[', 'CC'), 'NN'),
#  (('32', 'CD'), 'NN'),
#  ((']', 'NN'), 'NN'),
#  (('During', 'IN'), 'NN'),
#  (('his', 'PRP$'), 'NN'),
#  (('childhood', 'NN'), 'NN'),
#  (('he', 'PRP'), 'NN'),
#  (('had', 'VBD'), 'NN'),
#  (('an', 'DT'), 'NN'),
#  (('interest', 'NN'), 'NN'),
#  (('in', 'IN'), 'NN'),
#  (('reading', 'NN'), 'NN'),
#  (('and', 'CC'), 'NN'),
#  (('often', 'RB'), 'NN'),
#  (('did', 'VBD'), 'NN'),
#  (('so', 'RB'), 'NN'),
#  (('for', 'IN'), 'NN'),
#  (('hours', 'NNS'), 'NN'),
#  (('at', 'IN'), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('time', 'NN'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('[', 'VB'), 'NN'),
#  (('35', 'CD'), 'NN'),
#  ((']', 'NN'), 'NN'),
#  (('At', 'IN'), 'NN'),
#  (('What', 'WP'), 'NN'),
#  (('age', 'NN'), 'NN'),
#  (('did', 'VBD'), 'NN'),
#  (('Musk', 'NNP'), 'NN'),
#  (('got', 'VBD'), 'NN'),
#  (('interested', 'JJ'), 'NN'),
#  (('in', 'IN'), 'NN'),
#  (('computing', 'VBG'), 'NN'),
#  (('?', '.'), 'NN'),
#  (('At', 'IN'), 'NN'),
#  (('age', 'NN'), 'NN'),
#  (('10', 'CD'), 'NN'),
#  ((',', ','), 'NN'),
#  (('he', 'PRP'), 'NN'),
#  (('developed', 'VBD'), 'NN'),
#  (('an', 'DT'), 'NN'),
#  (('interest', 'NN'), 'NN'),
#  (('in', 'IN'), 'NN'),
#  (('computing', 'VBG'), 'NN'),
#  (('with', 'IN'), 'NN'),
#  (('the', 'DT'), 'NN'),
#  (('Commodore', 'NNP'), 'NN'),
#  (('VIC-20', 'NNP'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('[', 'VB'), 'NN'),
#  (('36', 'CD'), 'NN'),
#  ((']', 'NN'), 'NN'),
#  (('He', 'PRP'), 'NN'),
#  (('taught', 'VBD'), 'NN'),
#  (('himself', 'PRP'), 'NN'),
#  (('computer', 'NN'), 'NN'),
#  (('programming', 'VBG'), 'NN'),
#  (('at', 'IN'), 'NN'),
#  (('the', 'DT'), 'NN'),
#  (('age', 'NN'), 'NN'),
#  (('of', 'IN'), 'NN'),
#  (('12', 'CD'), 'NN'),
#  ((',', ','), 'NN'),
#  (('sold', 'VBD'), 'NN'),
#  (('the', 'DT'), 'NN'),
#  (('code', 'NN'), 'NN'),
#  (('for', 'IN'), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('BASIC-based', 'JJ'), 'NN'),
#  (('video', 'NN'), 'NN'),
#  (('game', 'NN'), 'NN'),
#  (('he', 'PRP'), 'NN'),
#  (('created', 'VBD'), 'NN'),
#  (('called', 'VBN'), 'NN'),
#  (('Blastar', 'NNP'), 'NN'),
#  ((',', ','), 'NN'),
#  (('to', 'TO'), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('magazine', 'NN'), 'NN'),
#  (('called', 'VBN'), 'NN'),
#  (('PC', 'NN'), 'NN'),
#  (('and', 'CC'), 'NN'),
#  (('Office', 'NNP'), 'NN'),
#  (('Technology', 'NNP'), 'NN'),
#  ((',', ','), 'NN'),
#  (('for', 'IN'), 'NN'),
#  (('approximately', 'RB'), 'NN'),
#  (('$', '$'), 'NN'),
#  (('500', 'CD'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('[', 'VB'), 'NN'),
#  (('37', 'CD'), 'NN'),
#  ((']', 'NNP'), 'NN'),
#  (('[', 'VBD'), 'NN'),
#  (('38', 'CD'), 'NN'),
#  ((']', 'NN'), 'NN'),
#  (('A', 'NNP'), 'NN'),
#  (('web', 'JJ'), 'NN'),
#  (('version', 'NN'), 'NN'),
#  (('of', 'IN'), 'NN'),
#  (('the', 'DT'), 'NN'),
#  (('game', 'NN'), 'NN'),
#  (('is', 'VBZ'), 'NN'),
#  (('available', 'JJ'), 'NN'),
#  (('online', 'NN'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('[', 'CC'), 'NN'),
#  (('37', 'CD'), 'NN'),
#  ((']', 'JJ'), 'NN'),
#  (('[', '$'), 'NN'),
#  (('39', 'CD'), 'NN'),
#  ((']', 'NNP'), 'NN'),
#  (('Musk', 'NNP'), 'NN'),
#  (('was', 'VBD'), 'NN'),
#  (('severely', 'RB'), 'NN'),
#  (('bullied', 'VBN'), 'NN'),
#  (('throughout', 'IN'), 'NN'),
#  (('his', 'PRP$'), 'NN'),
#  (('childhood', 'NN'), 'NN'),
#  ((',', ','), 'NN'),
#  (('and', 'CC'), 'NN'),
#  (('was', 'VBD'), 'NN'),
#  (('once', 'RB'), 'NN'),
#  (('hospitalized', 'VBN'), 'NN'),
#  (('when', 'WRB'), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('group', 'NN'), 'NN'),
#  (('of', 'IN'), 'NN'),
#  (('boys', 'NNS'), 'NN'),
#  (('threw', 'VBD'), 'NN'),
#  (('him', 'PRP'), 'NN'),
#  (('down', 'RP'), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('flight', 'NN'), 'NN'),
#  (('of', 'IN'), 'NN'),
#  (('stairs', 'NNS'), 'NN'),
#  (('and', 'CC'), 'NN'),
#  (('then', 'RB'), 'NN'),
#  (('beat', 'VBD'), 'NN'),
#  (('him', 'PRP'), 'NN'),
#  (('until', 'IN'), 'NN'),
#  (('he', 'PRP'), 'NN'),
#  (('lost', 'VBD'), 'NN'),
#  (('consciousness', 'NN'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('[', 'CC'), 'NN'),
#  (('40', 'CD'), 'NN'),
#  ((']', 'JJ'), 'NN'),
#  (('Musk', 'NNP'), 'NN'),
#  (('was', 'VBD'), 'NN'),
#  (('initially', 'RB'), 'NN'),
#  (('educated', 'VBN'), 'NN'),
#  (('at', 'IN'), 'NN'),
#  (('private', 'JJ'), 'NN'),
#  (('schools', 'NNS'), 'NN'),
#  ((',', ','), 'NN'),
#  (('attending', 'VBG'), 'NN'),
#  (('the', 'DT'), 'NN'),
#  (('English-speaking', 'JJ'), 'NN'),
#  (('Waterkloof', 'NNP'), 'NN'),
#  (('House', 'NNP'), 'NN'),
#  (('Preparatory', 'NNP'), 'NN'),
#  (('School', 'NNP'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('Mr.', 'NNP'), 'NN'),
#  (('Singh', 'NNP'), 'NN'),
#  (('helped', 'VBD'), 'NN'),
#  (('Musk', 'NNP'), 'NN'),
#  (('during', 'IN'), 'NN'),
#  (('his', 'PRP$'), 'NN'),
#  (('initial', 'JJ'), 'NN'),
#  (('days', 'NNS'), 'NN'),
#  (('when', 'WRB'), 'NN'),
#  (('he', 'PRP'), 'NN'),
#  (('was', 'VBD'), 'NN'),
#  (('severely', 'RB'), 'NN'),
#  (('bullied', 'VBN'), 'NN'),
#  (('during', 'IN'), 'NN'),
#  (('his', 'PRP$'), 'NN'),
#  (('childhood', 'NN'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('Musk', 'NNP'), 'NN'),
#  (('later', 'RB'), 'NN'),
#  (('graduated', 'VBD'), 'NN'),
#  (('from', 'IN'), 'NN'),
#  (('Pretoria', 'NNP'), 'NN'),
#  (('Boys', 'NNP'), 'NN'),
#  (('High', 'NNP'), 'NN'),
#  (('School', 'NNP'), 'NN'),
#  (('and', 'CC'), 'NN'),
#  (('moved', 'VBD'), 'NN'),
#  (('to', 'TO'), 'NN'),
#  (('Canada', 'NNP'), 'NN'),
#  (('in', 'IN'), 'NN'),
#  (('June', 'NNP'), 'NN'),
#  (('1989', 'CD'), 'NN'),
#  ((',', ','), 'NN'),
#  (('just', 'RB'), 'NN'),
#  (('before', 'IN'), 'NN'),
#  (('his', 'PRP$'), 'NN'),
#  (('18th', 'CD'), 'NN'),
#  (('birthday', 'NN'), 'NN'),
#  ((',', ','), 'NN'),
#  (('[', 'RB'), 'NN'),
#  (('41', 'CD'), 'NN'),
#  ((']', 'NNS'), 'NN'),
#  (('after', 'IN'), 'NN'),
#  (('obtaining', 'VBG'), 'NN'),
#  (('Canadian', 'JJ'), 'NN'),
#  (('citizenship', 'NN'), 'NN'),
#  (('through', 'IN'), 'NN'),
#  (('his', 'PRP$'), 'NN'),
#  (('Canadian-born', 'JJ'), 'NN'),
#  (('mother', 'NN'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('[', '$'), 'NN'),
#  (('42', 'CD'), 'NN'),
#  ((']', 'NNP'), 'NN'),
#  (('[', 'VBD'), 'NN'),
#  (('43', 'CD'), 'NN'),
#  ((']', 'NNS'), 'NN'),
#  (('Although', 'IN'), 'NN'),
#  (('at', 'IN'), 'NN'),
#  (('the', 'DT'), 'NN'),
#  (('time', 'NN'), 'NN'),
#  (('Musk', 'NNP'), 'NN'),
#  (('had', 'VBD'), 'NN'),
#  (('to', 'TO'), 'NN'),
#  (('register', 'VB'), 'NN'),
#  (('to', 'TO'), 'NN'),
#  (('become', 'VB'), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('Canadian', 'JJ'), 'NN'),
#  (('citizen', 'NN'), 'NN'),
#  ((',', ','), 'NN'),
#  (('Bill', 'NNP'), 'NN'),
#  (('C-37', 'NNP'), 'NN'),
#  ((',', ','), 'NN'),
#  (('which', 'WDT'), 'NN'),
#  (('came', 'VBD'), 'NN'),
#  (('into', 'IN'), 'NN'),
#  (('law', 'NN'), 'NN'),
#  (('in', 'IN'), 'NN'),
#  (('April', 'NNP'), 'NN'),
#  (('of', 'IN'), 'NN'),
#  (('2009', 'CD'), 'NN'),
#  ((',', ','), 'NN'),
#  (('effectively', 'RB'), 'NN'),
#  (('made', 'VBD'), 'NN'),
#  (('his', 'PRP$'), 'NN'),
#  (('Canadian', 'JJ'), 'NN'),
#  (('citizenship', 'NN'), 'NN'),
#  (('retroactive', 'JJ'), 'NN'),
#  (('to', 'TO'), 'NN'),
#  (('his', 'PRP$'), 'NN'),
#  (('birth', 'NN'), 'NN'),
#  (('since', 'IN'), 'NN'),
#  (('he', 'PRP'), 'NN'),
#  (('was', 'VBD'), 'NN'),
#  (('born', 'VBN'), 'NN'),
#  (('in', 'IN'), 'NN'),
#  (('the', 'DT'), 'NN'),
#  (('first', 'JJ'), 'NN'),
#  (('generation', 'NN'), 'NN'),
#  (('abroad', 'RB'), 'NN'),
#  (('to', 'TO'), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('Canadian-born', 'JJ'), 'NN'),
#  (('mother', 'NN'), 'NN'),
#  (('.', '.'), 'NN'),
#  (('Therefore', 'RB'), 'NN'),
#  ((',', ','), 'NN'),
#  (('with', 'IN'), 'NN'),
#  (('the', 'DT'), 'NN'),
#  (('law', 'NN'), 'NN'),
#  (('change', 'NN'), 'NN'),
#  ((',', ','), 'NN'),
#  (('he', 'PRP'), 'NN'),
#  (('is', 'VBZ'), 'NN'),
#  (('considered', 'VBN'), 'NN'),
#  (('to', 'TO'), 'NN'),
#  (('have', 'VB'), 'NN'),
#  (('always', 'RB'), 'NN'),
#  (('been', 'VBN'), 'NN'),
#  (('a', 'DT'), 'NN'),
#  (('Canadian', 'JJ'), 'NN'),
#  (('citizen', 'NN'), 'NN'),
#  (('by', 'IN'), 'NN'),
#  (('birth', 'NN'), 'NN'),
#  (('.', '.'), 'NN')]

# %% [markdown]
# # Part - 2
#
# ## Create your own Tagger using the following rules
#
# ## Let's try to understand some **Parts Of Speech**
#
# ## 1. **Possesion Noun (NN)** - any word which ends with **'s**
#    ### > ***Jennifer’s*** new handbag matches her shoes perfectly
# ## 2. **Gerund (VBG)** - any word which ends with **ing**
#    ### > ***Swimming*** in the ocean has been Sharon’s passion since she was five years old.
# ## 3. **Simple Past (VBD)** - any word which ends with **ed**
#    ### > We ***crossed*** the Channel yesterday.
# ## 4. **Modal (MD)** - any word which ends with **ould**
#    ### > He **should** not be late
# ## 5. **Third Singular Present (VBZ)** - any word which ends with **es**
#    ### > He **misses** her so much
# ## 6. **Numbers (CD)** - any number integer or decimal
#    ### > 24.90
# ## 7. **Plural Nouns (NNS)** - any word ending with **s**
#   ### > You stole my **ideas** and didn’t give me any credit.

# %%
pattern = [(r'.*\'s$','NN$'),#any word which ends with 's
           (r'.*ing$','VGB'),#any word which ends with ing
           (r'.*ed$','VBD'),#any word which ends with ed
           (r'.*ould$','MD'),#any word which ends with ould
           (r'.*es$','VBZ'),#any word which ends with es
           (r'\d\.?\d?','CD'),#any number integer or decimal
           (r'.*s$','NNS')]#any word ending with s
tagger_new = nltk.RegexpTagger(pattern)
sentence = "Jennifer's learning rate should be rated arounds 28.90 in 1991. When he misses her."
tagger_new.tag(sentence.split())
# Out:
# [("Jennifer's", 'NN$'),
#  ('learning', 'VGB'),
#  ('rate', None),
#  ('should', 'MD'),
#  ('be', None),
#  ('rated', 'VBD'),
#  ('arounds', 'NNS'),
#  ('28.90', 'CD'),
#  ('in', None),
#  ('1991.', 'CD'),
#  ('When', None),
#  ('he', None),
#  ('misses', 'VBZ'),
#  ('her.', None)]
